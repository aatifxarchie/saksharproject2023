# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# User data sheet

# %%
data = pd.read_excel("sakshar_data.xlsx")
data['Gender'] = data['Gender'].map({"M" : 1 , "F" : 0})
print(data)
# Out:
#        Name  Age  Gender  Time(s)  Score(after 120s)
# 0     Aarav    5       1      136                 70
# 1     Aisha    7       0      155                 30
# 2     Arjun    8       1      128                 60
# 3     Anika    6       0      140                 90
# 4       Dev    4       1      120                 70
# 5    Ishaan    9       1      165                 20
# 6     Kavya    7       0      142                100
# 7     Krish    6       1      130                 50
# 8     Meera    5       0      125                 90
# 9      Neel    8       1      152                 80
# 10     Riya    4       0      115                100
# 11    Rohan    6       1      138                 80
# 12   Sanaya    9       0      160                 70
# 13    Shaan    7       1      145                 50
# 14    Aanya    5       0      122                 80
# 15    Aryan    6       1      137                 40
# 16    Avani    8       0      150                 70
# 17    Eesha    5       0      127                 50
# 18     Isha    7       0      148                 30
# 19    Kabir    4       1      112                 60
# 20    Kiara    9       0      163                 80
# 21   Nivaan    8       1      158                 30
# 22     Rhea    6       0      135                100
# 23    Sahil    7       1      144                 20
# 24  Samaira    5       0      123                 50
# 25      Ved    6       1      136                 60
# 26     Zara    8       0      149                 40
# 27  Aradhya    4       0      119                 90
# 28   Vivaan    7       1      146                 70
# 29    Barun    6       1      121                100

# %%
data = pd.read_excel("sakshar_data.xlsx")
data['Gender'] = data['Gender'].map({"M" : 1 , "F" : 0})
print(data)

# %% [markdown]
# Time taken by each student

# %%
plt.barh(data['Name'],data['Time(s)'],height = 0.5,color="green",label = "Time")
plt.tight_layout()
plt.legend()
plt.show()
